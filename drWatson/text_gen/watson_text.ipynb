# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2

gpt2.download_gpt2(model_name='124M')
# Out:
# TensorFlow 1.x selected.
# ...
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# Fetching checkpoint: 1.05Mit [00:00, 288Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 130Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 464Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:04, 124Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 283Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 167Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 178Mit/s]

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
tuning_file = '/content/drive/My Drive/Colab Notebooks/CS485/final_project(not_repo)/sherlock.txt'

new_session = gpt2.start_tf_sess()

gpt2.finetune(sess=new_session,
              dataset=tuning_file,
              model_name='124M',
              steps=1000,
              restore_from='fresh',
              run_name='run0',
              print_every=10,
              sample_every=200,
              save_every=500)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# ...

# %%
# gpt2.load_gpt2(sess=new_session, run_name='run0')

gen_file = '/content/drive/My Drive/Colab Notebooks/CS485/final_project(not_repo)/gen_sherlock.txt'
gpt2.generate_to_file(sess=new_session,
                      destination_path=gen_file,
                      length=500,
                      run_name='run0',
                      temperature=1.0,
                      nsamples=20,
                      batch_size=4)
